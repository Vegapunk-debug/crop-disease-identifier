# %%
import os
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
import timm
import albumentations as A
from albumentations.pytorch import ToTensorV2
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
import numpy as np


device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Mathematical engine bound to: {device}")
# Out:
# Mathematical engine bound to: mps

# %%
print("Authenticating with Kaggle API...")
api = KaggleApi()
api.authenticate()

# The specific Kaggle endpoint for the PlantVillage subset
dataset_identifier = 'emmarex/plantdisease'

print(f"Initiating high-speed download for {dataset_identifier}...")
# This will download the zip file directly into the dataset directory
api.dataset_download_files(dataset_identifier, path=DATASET_DIR, unzip=False)

# Rename the downloaded file to a predictable state
downloaded_zip = os.path.join(DATASET_DIR, 'plantdisease.zip')
print(f"Procurement successful. Payload secured at: {downloaded_zip}")
